# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_loss(log_file):
    losses = []
    with open(log_file, "r") as _f:
        for line in _f.readlines():
            loss = float(line.split(" ")[-1])
            losses.append(loss)

    # print(losses)
    plt.plot(np.arange(len(losses)), losses, label=log_file, alpha=0.7)
    plt.legend()
    # plt.show()

# %%
plot_loss("nn.c.log")
plot_loss("pytorch.log")
plt.savefig("figs/nn.c vs pytorch (CPU).pdf")
